# %% [markdown]
# # Python for Science Calculate
#
# ## Ipython Notebook Study
# ### Mathjax Test
# $e^{i\pi} + 1 =0$
#
# It looks like fine, no need to install mathjax to local
#
# ### Magic Command

# %%
# %matplotlib inline
import pylab as pl
pl.seed(1)
data = pl.randn(100)
pl.plot(data)

# %%
# %matplotlib qt5
pl.plot(data)

# %% [markdown]
# ## NumPy-快速处理数据
